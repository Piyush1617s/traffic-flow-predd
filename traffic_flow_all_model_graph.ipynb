# %%
import pandas as pd

results = pd.read_excel(r"C:\Users\ASUS\OneDrive\Desktop\EXEMPTED\CODED\ML\traffic flow prediction.xlsx")

print(results.head())
# Out:
#                             model    mae    mse    rmse
# 0  lstm for all junction together  17.00  22.225    NaN
# 1  gru for all junctions together  17.59  23.090    NaN
# 2  cnn for all junctions together  18.44  23.880    NaN
# 3           encoder decoder (t+1)  16.14     NaN  22.16
# 4           encoder decoder (t+2)  19.20     NaN  24.75

# %%
plt.figure(figsize=(20,8))
plt.bar(results["model"], results["rmse"])
plt.xticks(rotation=90)
plt.ylabel("RMSE")
plt.title("RMSE Comparison — All Models")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18,7))

plt.bar(results["model"], results["mae"])

plt.xticks(rotation=90)
plt.ylabel("MAE")
plt.title("MAE Comparison of All Models")

plt.tight_layout()
plt.show()
